# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 데이터 로드

train = pd.read_parquet('/content/drive/MyDrive/이용주/train_fin.parquet')
train.head()
# Out:
#               id  base_date  day_of_week  base_hour  lane_count  road_rating  \
# 0  TRAIN_0000000   20220623            1         17           1          106
# 1  TRAIN_0000001   20220728            1         21           2          103
# 2  TRAIN_0000002   20211010            4          7           2          103
# 3  TRAIN_0000003   20220311            0         13           2          107
# 4  TRAIN_0000004   20211005            6          8           2          103
#
#    road_name  multi_linked  connect_code  maximum_speed_limit  ...  \
# 0  지방도1112호선             0             0                 60.0  ...
# 1   일반국도11호선             0             0                 60.0  ...
# 2   일반국도16호선             0             0                 80.0  ...
# 3        태평로             0             0                 50.0  ...
# 4   일반국도12호선             0             0                 80.0  ...
#
#    start_latitude  start_longitude  start_turn_restricted  end_node_name  \
# 0       33.427747       126.662612                      0          제3교래교
# 1       33.500730       126.529107                      1         KAL사거리
# 2       33.279145       126.368598                      0           상창육교
# 3       33.246081       126.567204                      0           서현주택
# 4       33.462214       126.326551                      0           애월입구
#
#   end_latitude  end_longitude  end_turn_restricted  target weekend  month
# 0    33.427749     126.662335                    0    52.0       0      6
# 1    33.504811     126.526240                    0    30.0       0      7
# 2    33.280072     126.362147                    0    61.0       1     10
# 3    33.245565     126.566228                    0    20.0       0      3
# 4    33.462677     126.330152                    0    38.0       0     10
#
# [5 rows x 25 columns]

# %%
# 원핫인코딩 데이터 전처리 후에 아래 데이터 나누는 코드 실행

dawn = [0,1,2,3,4,5]
morning = [6,7,8,9,10,11]
daytime = [12,13,14,15,16,17]
night = [18,19,20,21,22,23]

hour_label = []

for row in train['base_hour']:
    if row in dawn:
        hour_label.append(0)   # 새벽 0
    elif row in morning:
        hour_label.append(1)   # 오전 1
    elif row in daytime:
        hour_label.append(2)   # 오후 2
    elif row in night:
        hour_label.append(3)   # 저녁 3

train['hour_label'] = hour_label
train
# Out:
#                     id  base_date  day_of_week  base_hour  lane_count  \
# 0        TRAIN_0000000   20220623            1         17           1
# 1        TRAIN_0000001   20220728            1         21           2
# 2        TRAIN_0000002   20211010            4          7           2
# 3        TRAIN_0000003   20220311            0         13           2
# 4        TRAIN_0000004   20211005            6          8           2
# ...                ...        ...          ...        ...         ...
# 4701212  TRAIN_4701212   20211104            1         16           1
# 4701213  TRAIN_4701213   20220331            1          2           2
# 4701214  TRAIN_4701214   20220613            3         22           2
# 4701215  TRAIN_4701215   20211020            2          2           2
# 4701216  TRAIN_4701216   20211019            6          6           2
#
#          road_rating  road_name  multi_linked  connect_code  \
# 0                106  지방도1112호선             0             0
# 1                103   일반국도11호선             0             0
# 2                103   일반국도16호선             0             0
# 3                107        태평로             0             0
# 4                103   일반국도12호선             0             0
# ...              ...        ...           ...           ...
# 4701212          107          -             0             0
# 4701213          107          -             0             0
# 4701214          103   일반국도12호선             0             0
# 4701215          103   일반국도95호선             0             0
# 4701216          107        경찰로             0             0
#
#          maximum_speed_limit  ...  start_longitude  start_turn_restricted  \
# 0                       60.0  ...       126.662612                      0
# 1                       60.0  ...       126.529107                      1
# 2                       80.0  ...       126.368598                      0
# 3                       50.0  ...       126.567204                      0
# 4                       80.0  ...       126.326551                      0
# ...                      ...  ...              ...                    ...
# 4701212                 50.0  ...       126.278125                      0
# 4701213                 80.0  ...       126.424368                      0
# 4701214                 60.0  ...       126.912579                      0
# 4701215                 80.0  ...       126.431817                      0
# 4701216                 60.0  ...       126.508940                      0
#
#          end_node_name  end_latitude end_longitude  end_turn_restricted  \
# 0                제3교래교     33.427749    126.662335                    0
# 1               KAL사거리     33.504811    126.526240                    0
# 2                 상창육교     33.280072    126.362147                    0
# 3                 서현주택     33.245565    126.566228                    0
# 4                 애월입구     33.462677    126.330152                    0
# ...                ...           ...           ...                  ...
# 4701212           금덕해운     33.420955    126.273750                    0
# 4701213            광삼교     33.472525    126.424890                    0
# 4701214          성산교차로     33.444121    126.912948                    0
# 4701215         관광대학입구     33.444996    126.433332                    0
# 4701216           시민공원     33.257130    126.510364                    0
#
#          target  weekend month  hour_label
# 0          52.0        0     6           2
# 1          30.0        0     7           3
# 2          61.0        1    10           1
# 3          20.0        0     3           2
# 4          38.0        0    10           1
# ...         ...      ...   ...         ...
# 4701212    20.0        0    11           2
# 4701213    65.0        0     3           0
# 4701214    30.0        0     6           3
# 4701215    73.0        0    10           0
# 4701216    35.0        0    10           1
#
# [4701217 rows x 26 columns]

# %%
# 데이터 수정후 데이터 분리 진행 부탁드립니다

from sklearn.utils import shuffle

tr = shuffle(train.sort_values('base_date')[train['base_date'] < 20220701])
te = shuffle(train.sort_values('base_date')[train['base_date'] > 20220631])

y_train = tr['target']
X_train = tr.drop(['day_of_week', 'multi_linked', 'connect_code', 'height_restricted', 'id','base_date', 'target','road_name', 'start_node_name', 'end_node_name','vehicle_restricted'], axis=1)


y_test = te['target']
X_test = te.drop(['day_of_week', 'multi_linked', 'connect_code', 'height_restricted', 'id','base_date', 'target','road_name', 'start_node_name', 'end_node_name','vehicle_restricted'], axis=1)


print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# (4426522, 15)
# (4426522,)
# (274695, 15)

# %% [markdown]
# ## 저장된 데이터 셋이 공휴일 컬럼이 추가된 상태라
# ## 기본 파라미터상태에서의 원핫인코딩 결과가 의미가 없을듯 합니다. 비교군이 달라져서요
# ## 기본 데이터에서의 기본 파라미터인데 데이터가 공휴일이 추가된 데이터라
# ## 아래 파라미터 하나만으로 원핫인코딩 테스트 진행하셔도 될듯합니다!!

# %%
# 원핫인코딩(시간) 테스트

min_num = 10
min_stack = 0
stop_num = 3

LR = lgb.LGBMRegressor(random_state = 42,
                       max_depth = 19,
                       num_leaves = 187,
                       n_estimators = 1000,
                       learning_rate = 0.3,
                      ).fit(X_train, y_train)

pred = LR.predict(X_test)
mae = mean_absolute_error(pred, y_test)


# mae 값이 3.55와 근접하다면 for문으로 파라미터 테스트 간단하게 또 진행하도록 하겠습니다.
# 근접하다면 말해주세용
print('in_holidays : ', mae)
# Out:
# in_holidays :  3.553321935753566

# %% [markdown]
# # 스케일링 테스트

# %%
# 데이터 로드

train = pd.read_parquet('/content/drive/MyDrive/이용주/train_fin.parquet')
train.head()
# Out:
#               id  base_date  day_of_week  base_hour  lane_count  road_rating  \
# 0  TRAIN_0000000   20220623            1         17           1          106
# 1  TRAIN_0000001   20220728            1         21           2          103
# 2  TRAIN_0000002   20211010            4          7           2          103
# 3  TRAIN_0000003   20220311            0         13           2          107
# 4  TRAIN_0000004   20211005            6          8           2          103
#
#    road_name  multi_linked  connect_code  maximum_speed_limit  ...  \
# 0  지방도1112호선             0             0                 60.0  ...
# 1   일반국도11호선             0             0                 60.0  ...
# 2   일반국도16호선             0             0                 80.0  ...
# 3        태평로             0             0                 50.0  ...
# 4   일반국도12호선             0             0                 80.0  ...
#
#    start_latitude  start_longitude  start_turn_restricted  end_node_name  \
# 0       33.427747       126.662612                      0          제3교래교
# 1       33.500730       126.529107                      1         KAL사거리
# 2       33.279145       126.368598                      0           상창육교
# 3       33.246081       126.567204                      0           서현주택
# 4       33.462214       126.326551                      0           애월입구
#
#   end_latitude  end_longitude  end_turn_restricted  target weekend  month
# 0    33.427749     126.662335                    0    52.0       0      6
# 1    33.504811     126.526240                    0    30.0       0      7
# 2    33.280072     126.362147                    0    61.0       1     10
# 3    33.245565     126.566228                    0    20.0       0      3
# 4    33.462677     126.330152                    0    38.0       0     10
#
# [5 rows x 25 columns]

# %%
train_df = train.copy()

# %%
train_df=train_df.loc[:,['maximum_speed_limit', 'target']]
train_df
# Out:
#          maximum_speed_limit  target
# 0                       60.0    52.0
# 1                       60.0    30.0
# 2                       80.0    61.0
# 3                       50.0    20.0
# 4                       80.0    38.0
# ...                      ...     ...
# 4701212                 50.0    20.0
# 4701213                 80.0    65.0
# 4701214                 60.0    30.0
# 4701215                 80.0    73.0
# 4701216                 60.0    35.0
#
# [4701217 rows x 2 columns]

# %%
# 스케일링처리 코드

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_minmax = scaler.fit_transform(train_df)

minmax = pd.DataFrame(df_minmax)
minmax
# Out:
#            0         1
# 0        0.6  0.455357
# 1        0.6  0.258929
# 2        1.0  0.535714
# 3        0.4  0.169643
# 4        1.0  0.330357
# ...      ...       ...
# 4701212  0.4  0.169643
# 4701213  1.0  0.571429
# 4701214  0.6  0.258929
# 4701215  1.0  0.642857
# 4701216  0.6  0.303571
#
# [4701217 rows x 2 columns]

# %%
minmax.rename(columns = {0:'maximum_speed_limit_scale',1:'target_scale'},inplace=True)

# %%
minmax
# Out:
#          maximum_speed_limit_scale  target_scale
# 0                              0.6      0.455357
# 1                              0.6      0.258929
# 2                              1.0      0.535714
# 3                              0.4      0.169643
# 4                              1.0      0.330357
# ...                            ...           ...
# 4701212                        0.4      0.169643
# 4701213                        1.0      0.571429
# 4701214                        0.6      0.258929
# 4701215                        1.0      0.642857
# 4701216                        0.6      0.303571
#
# [4701217 rows x 2 columns]

# %%
train=pd.concat([train, minmax], axis=1)
train
# Out:
#                     id  base_date  day_of_week  base_hour  lane_count  \
# 0        TRAIN_0000000   20220623            1         17           1
# 1        TRAIN_0000001   20220728            1         21           2
# 2        TRAIN_0000002   20211010            4          7           2
# 3        TRAIN_0000003   20220311            0         13           2
# 4        TRAIN_0000004   20211005            6          8           2
# ...                ...        ...          ...        ...         ...
# 4701212  TRAIN_4701212   20211104            1         16           1
# 4701213  TRAIN_4701213   20220331            1          2           2
# 4701214  TRAIN_4701214   20220613            3         22           2
# 4701215  TRAIN_4701215   20211020            2          2           2
# 4701216  TRAIN_4701216   20211019            6          6           2
#
#          road_rating  road_name  multi_linked  connect_code  \
# 0                106  지방도1112호선             0             0
# 1                103   일반국도11호선             0             0
# 2                103   일반국도16호선             0             0
# 3                107        태평로             0             0
# 4                103   일반국도12호선             0             0
# ...              ...        ...           ...           ...
# 4701212          107          -             0             0
# 4701213          107          -             0             0
# 4701214          103   일반국도12호선             0             0
# 4701215          103   일반국도95호선             0             0
# 4701216          107        경찰로             0             0
#
#          maximum_speed_limit  ...  start_turn_restricted  end_node_name  \
# 0                       60.0  ...                      0          제3교래교
# 1                       60.0  ...                      1         KAL사거리
# 2                       80.0  ...                      0           상창육교
# 3                       50.0  ...                      0           서현주택
# 4                       80.0  ...                      0           애월입구
# ...                      ...  ...                    ...            ...
# 4701212                 50.0  ...                      0           금덕해운
# 4701213                 80.0  ...                      0            광삼교
# 4701214                 60.0  ...                      0          성산교차로
# 4701215                 80.0  ...                      0         관광대학입구
# 4701216                 60.0  ...                      0           시민공원
#
#          end_latitude  end_longitude end_turn_restricted  target  weekend  \
# 0           33.427749     126.662335                   0    52.0        0
# 1           33.504811     126.526240                   0    30.0        0
# 2           33.280072     126.362147                   0    61.0        1
# 3           33.245565     126.566228                   0    20.0        0
# 4           33.462677     126.330152                   0    38.0        0
# ...               ...            ...                 ...     ...      ...
# 4701212     33.420955     126.273750                   0    20.0        0
# 4701213     33.472525     126.424890                   0    65.0        0
# 4701214     33.444121     126.912948                   0    30.0        0
# 4701215     33.444996     126.433332                   0    73.0        0
# 4701216     33.257130     126.510364                   0    35.0        0
#
#          month maximum_speed_limit_scale  target_scale
# 0            6                       0.6      0.455357
# 1            7                       0.6      0.258929
# 2           10                       1.0      0.535714
# 3            3                       0.4      0.169643
# 4           10                       1.0      0.330357
# ...        ...                       ...           ...
# 4701212     11                       0.4      0.169643
# 4701213      3                       1.0      0.571429
# 4701214      6                       0.6      0.258929
# 4701215     10                       1.0      0.642857
# 4701216     10                       0.6      0.303571
#
# [4701217 rows x 27 columns]

# %%
# 데이터 수정후 데이터 분리 진행 부탁드립니다

from sklearn.utils import shuffle

tr = shuffle(train.sort_values('base_date')[train['base_date'] < 20220701])
te = shuffle(train.sort_values('base_date')[train['base_date'] > 20220631])

y_train = tr['target_scale']
X_train = tr.drop(['day_of_week', 'multi_linked', 'connect_code', 'height_restricted', 'id','base_date', 'target','road_name', 'start_node_name', 'end_node_name','vehicle_restricted','maximum_speed_limit','target'], axis=1)


y_test = te['target_scale']
X_test = te.drop(['day_of_week', 'multi_linked', 'connect_code', 'height_restricted', 'id','base_date', 'target','road_name', 'start_node_name', 'end_node_name','vehicle_restricted', 'maximum_speed_limit', 'target'], axis=1)


print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# (4426522, 15)
# (4426522,)
# (274695, 15)

# %%
min_num = 10
min_stack = 0
stop_num = 3

LR = lgb.LGBMRegressor(random_state = 42,
                       max_depth = 19,
                       num_leaves = 187,
                       n_estimators = 1000,
                       learning_rate = 0.6,
                      ).fit(X_train, y_train)

pred = LR.predict(X_test)
mae = mean_absolute_error(pred, y_test)

# mae 값이 3.55와 근접하다면 for문으로 파라미터 테스트 간단하게 또 진행하도록 하겠습니다.
# 근접하다면 말해주세용
print('scaling : ', mae)
# Out:
# scaling :  1.3496954455654776e-05

# %% [markdown]
# ## 혹시 몰라서 for 문 파라미터 테스트 코드입니다

# %%
# 파라미터 테스트 범위 책정,
min_num_t = 15
max_num_t = 30

min_num = 10
min_stack = 0

# mae값이 3번째 커지면 for문이 종료됩니다
stop_num = 2


# 저는 파라미터 하나씩 주석을 풀면서 했습니다.
# 아래와 같이 하면 max_depth 파라미터 테스트
# max_depth를 주석처리하고 num_leaves만 주석을 해제하면 num_leaves 테스트

for i in range(min_num_t, max_num_t + 1):
    LR = lgb.LGBMRegressor(random_state = 42,
                           
                           max_depth = i,      # 19
                           
#                            num_leaves = i,     # 187
                           
#                            n_estimators = i,   # 1000
                           
#                            learning_rate = i,  # 0.6

                           
                           
                           
    #                            min_split_gain = (i / 100), # 0.0 mae값이 올라버림, 값이 오름에 따라
    #                            min_child_weight = (i / 1000), # 영향 미비
    #                            min_child_samples = i, # 20 미비
    #                            colsample_bytree = (i / 10), # 1.0이 젤 좋음
    #                            reg_lambda = (i / 100),
                          ).fit(X_train, y_train)

    pred = LR.predict(X_test)
    mae = mean_absolute_error(pred, y_test)

    print('파라미터 값  : ', i, ', mae : ', mae)
    
    if min_num > mae:
        min_stack = 0
        min_num = mae
    elif min_stack != stop_num:
        min_stack += 1
        min_num = mae
    elif min_stack == stop_num:
        break
